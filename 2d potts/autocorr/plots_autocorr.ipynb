# %%
import numpy as np

import matplotlib.pyplot as pylab

from scipy.optimize import curve_fit

from statistics import mean,stdev

# %%
m_35=[]
m_38=[]
m_41=[]
m_44=[]
m_47=[]
e_35=[]
e_38=[]
e_41=[]
e_44=[]
e_47=[]

m_10_35,e_10_35,m_10_38,e_10_38,m_10_41,e_10_41,m_10_44,e_10_44,m_10_47,e_10_47 = np.loadtxt('autocorr_10.txt', unpack=True)
m_15_35,e_15_35,m_15_38,e_15_38,m_15_41,e_15_41,m_15_44,e_15_44,m_15_47,e_15_47 = np.loadtxt('autocorr_15.txt', unpack=True)
m_20_35,e_20_35,m_20_38,e_20_38,m_20_41,e_20_41,m_20_44,e_20_44,m_20_47,e_20_47 = np.loadtxt('autocorr_20.txt', unpack=True)
m_25_35,e_25_35,m_25_38,e_25_38,m_25_41,e_25_41,m_25_44,e_25_44,m_25_47,e_25_47 = np.loadtxt('autocorr_25.txt', unpack=True)
m_30_35,e_30_35,m_30_38,e_30_38,m_30_41,e_30_41,m_30_44,e_30_44,m_30_47,e_30_47 = np.loadtxt('autocorr_30.txt', unpack=True)
m_35_35,e_35_35,m_35_38,e_35_38,m_35_41,e_35_41,m_35_44,e_35_44,m_35_47,e_35_47 = np.loadtxt('autocorr_35.txt', unpack=True)
m_40_35,e_40_35,m_40_38,e_40_38,m_40_41,e_40_41,m_40_44,e_40_44,m_40_47,e_40_47 = np.loadtxt('autocorr_40.txt', unpack=True)
m_45_35,e_45_35,m_45_38,e_45_38,m_45_41,e_45_41,m_45_44,e_45_44,m_45_47,e_45_47 = np.loadtxt('autocorr_45.txt', unpack=True)
m_50_35,e_50_35,m_50_38,e_50_38,m_50_41,e_50_41,m_50_44,e_50_44,m_50_47,e_50_47 = np.loadtxt('autocorr_50.txt', unpack=True)
m_55_35,e_55_35,m_55_38,e_55_38,m_55_41,e_55_41,m_55_44,e_55_44,m_55_47,e_55_47 = np.loadtxt('autocorr_55.txt', unpack=True)
m_60_35,e_60_35,m_60_38,e_60_38,m_60_41,e_60_41,m_60_44,e_60_44,m_60_47,e_60_47 = np.loadtxt('autocorr_60.txt', unpack=True)



m_35.append(m_10_35)
m_35.append(m_15_35)
m_35.append(m_20_35)
m_35.append(m_25_35)
m_35.append(m_30_35)
m_35.append(m_35_35)
m_35.append(m_40_35)
m_35.append(m_45_35)
m_35.append(m_50_35)
m_35.append(m_55_35)
m_35.append(m_60_35)

m_38.append(m_10_38)
m_38.append(m_15_38)
m_38.append(m_20_38)
m_38.append(m_25_38)
m_38.append(m_30_38)
m_38.append(m_35_38)
m_38.append(m_40_38)
m_38.append(m_45_38)
m_38.append(m_50_38)
m_38.append(m_55_38)
m_38.append(m_60_38)

m_41.append(m_10_41)
m_41.append(m_15_41)
m_41.append(m_20_41)
m_41.append(m_25_41)
m_41.append(m_30_41)
m_41.append(m_35_41)
m_41.append(m_40_41)
m_41.append(m_45_41)
m_41.append(m_50_41)
m_41.append(m_55_41)
m_41.append(m_60_41)

m_44.append(m_10_44)
m_44.append(m_15_44)
m_44.append(m_20_44)
m_44.append(m_25_44)
m_44.append(m_30_44)
m_44.append(m_35_44)
m_44.append(m_40_44)
m_44.append(m_45_44)
m_44.append(m_50_44)
m_44.append(m_55_44)
m_44.append(m_60_44)

m_47.append(m_10_47)
m_47.append(m_15_47)
m_47.append(m_20_47)
m_47.append(m_25_47)
m_47.append(m_30_47)
m_47.append(m_35_47)
m_47.append(m_40_47)
m_47.append(m_45_47)
m_47.append(m_50_47)
m_47.append(m_55_47)
m_47.append(m_60_47)

e_35.append(e_10_35)
e_35.append(e_15_35)
e_35.append(e_20_35)
e_35.append(e_25_35)
e_35.append(e_30_35)
e_35.append(e_35_35)
e_35.append(e_40_35)
e_35.append(e_45_35)
e_35.append(e_50_35)
e_35.append(e_55_35)
e_35.append(e_60_35)

e_38.append(e_10_38)
e_38.append(e_15_38)
e_38.append(e_20_38)
e_38.append(e_25_38)
e_38.append(e_30_38)
e_38.append(e_35_38)
e_38.append(e_40_38)
e_38.append(e_45_38)
e_38.append(e_50_38)
e_38.append(e_55_38)
e_38.append(e_60_38)

e_41.append(e_10_41)
e_41.append(e_15_41)
e_41.append(e_20_41)
e_41.append(e_25_41)
e_41.append(e_30_41)
e_41.append(e_35_41)
e_41.append(e_40_41)
e_41.append(e_45_41)
e_41.append(e_50_41)
e_41.append(e_55_41)
e_41.append(e_60_41)

e_44.append(e_10_44)
e_44.append(e_15_44)
e_44.append(e_20_44)
e_44.append(e_25_44)
e_44.append(e_30_44)
e_44.append(e_35_44)
e_44.append(e_40_44)
e_44.append(e_45_44)
e_44.append(e_50_44)
e_44.append(e_55_44)
e_44.append(e_60_44)

e_47.append(e_10_47)
e_47.append(e_15_47)
e_47.append(e_20_47)
e_47.append(e_25_47)
e_47.append(e_30_47)
e_47.append(e_35_47)
e_47.append(e_40_47)
e_47.append(e_45_47)
e_47.append(e_50_47)
e_47.append(e_55_47)
e_47.append(e_60_47)

# %%
import matplotlib.colors as mcolors
colors=['darkred','lightsalmon','orange','gold','olive','lawngreen','lightseagreen','dodgerblue','darkviolet','hotpink','crimson']
labels=['L=10','L=15','L=20','L=25','L=30','L=35','L=40','L=45','L=50','L=55','L=60']

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Magnetization autocorrelation at $\beta=0.35$", fontsize=15)
for i in range (0,len(m_35)):
    pylab.plot(np.arange(len(m_35[i])), m_35[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Magnetization autocorrelation at $\beta=0.38$", fontsize=15)
for i in range (0,len(m_38)):
    pylab.plot(np.arange(len(m_38[i])), m_38[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Magnetization autocorrelation at $\beta=0.41$", fontsize=15)
for i in range (0,len(m_41)):
    pylab.plot(np.arange(len(m_41[i])), m_41[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Magnetization autocorrelation at $\beta=0.44$", fontsize=15)
for i in range (0,len(m_44)):
    pylab.plot(np.arange(len(m_44[i])), m_44[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Magnetization autocorrelation at $\beta=0.47$", fontsize=15)
for i in range (0,len(m_47)):
    pylab.plot(np.arange(len(m_47[i])), m_47[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Energy autocorrelation at $\beta=0.35$", fontsize=15)
for i in range (0,len(e_35)):
    pylab.plot(np.arange(len(e_35[i])), e_35[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Energy autocorrelation at $\beta=0.38$", fontsize=15)
for i in range (0,len(e_38)):
    pylab.plot(np.arange(len(e_38[i])), e_38[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Energy autocorrelation at $\beta=0.41$", fontsize=15)
for i in range (0,len(e_41)):
    pylab.plot(np.arange(len(e_41[i])), e_41[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Energy autocorrelation at $ \beta=0.44$", fontsize=15)
for i in range (0,len(e_38)):
    pylab.plot(np.arange(len(e_44[i])), e_44[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')

pylab.minorticks_on()
pylab.title(r"Energy autocorrelation at $\beta=0.47$", fontsize=15)
for i in range (0,len(e_47)):
    pylab.plot(np.arange(len(e_47[i])), e_47[i], linestyle='-', marker='*', color=colors[i],label=labels[i])

pylab.legend()

# show the plot
pylab.show()

# %%
labels=['beta=0.35','beta=0.38','beta=0.41','beta=0.44','beta=0.47']

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')
pylab.title("Magnetization autocorrelation L=40", fontsize=15)
pylab.minorticks_on()
pylab.plot(np.arange(len(m_40_35)), m_40_35, linestyle='-', marker='*', color=colors[0],label=labels[0])
pylab.plot(np.arange(len(m_40_38)), m_40_38, linestyle='-', marker='*', color=colors[1],label=labels[1])
pylab.plot(np.arange(len(m_40_41)), m_40_41, linestyle='-', marker='*', color=colors[2],label=labels[2])
pylab.plot(np.arange(len(m_40_44)), m_40_44, linestyle='-', marker='*', color=colors[3],label=labels[3])
pylab.plot(np.arange(len(m_40_47)), m_40_47, linestyle='-', marker='*', color=colors[4],label=labels[4])

pylab.legend()

# show the plot
pylab.show()

# %%
#pylab.figure(9,7)
pylab.figure(figsize=(13, 11))
pylab.rc('font',size=18)
pylab.ylabel('$Corr$')
pylab.xlabel('$steps$')
pylab.title("Energy autocorrelation at L=40", fontsize=15)
pylab.minorticks_on()
pylab.plot(np.arange(len(e_40_35)), e_40_35, linestyle='-', marker='*', color=colors[0],label=labels[0])
pylab.plot(np.arange(len(e_40_38)), e_40_38, linestyle='-', marker='*', color=colors[1],label=labels[1])
pylab.plot(np.arange(len(e_40_41)), e_40_41, linestyle='-', marker='*', color=colors[2],label=labels[2])
pylab.plot(np.arange(len(e_40_44)), e_40_44, linestyle='-', marker='*', color=colors[3],label=labels[3])
pylab.plot(np.arange(len(e_40_47)), e_40_47, linestyle='-', marker='*', color=colors[4],label=labels[4])

pylab.legend()

# show the plot
pylab.show()
